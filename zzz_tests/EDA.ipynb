# %%
import pandas as pd

# %%
df = pd.read_csv("/home/shirshak/Pengwin_Submission_Portal/zzz_tests/occurances_of_labels.csv").drop('Unnamed: 0', axis=1)#.drop(['Unnamed: 0', 'Name'], axis=1)

# %%
df.columns
# Out:
# Index(['Label', 'Occurances'], dtype='object')

# %%
df
# Out:
#     Label  Occurances
# 0       0         100
# 1       1         100
# 2       2          45
# 3       3           7
# 4       4           1
# 5      11         100
# 6      12          66
# 7      13          36
# 8      14          11
# 9      15           1
# 10     16           1
# 11     21         100
# 12     22          64
# 13     23          34
# 14     24           9

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
print(df['Occurances'].describe())
# Out:
# count     15.000000
# mean      45.000000
# std       40.362642
# min        1.000000
# 25%        8.000000
# 50%       36.000000
# 75%       83.000000
# max      100.000000
# Name: Occurances, dtype: float64

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 3)
fig.set_figheight(6)
fig.set_figwidth(15)

ax[0].bar(df['Label'][1:5], df['Occurances'][1:5])
ax[0].set_xticks(df['Label'][1:5])
ax[0].set_yticks(df['Occurances'][1:5])
ax[0].set_xlabel('Fragments of Sacrum')
ax[0].set_ylabel('Occurrences in each image')

ax[1].bar(df['Label'][5:11], df['Occurances'][5:11])
ax[1].set_xticks(df['Label'][5:11])
ax[1].set_yticks(df['Occurances'][5:11])
ax[1].set_xlabel('Fragments of Left Iliac')
ax[1].set_ylabel('Occurrences in each image')

ax[2].bar(df['Label'][11:15], df['Occurances'][11:15])
ax[2].set_xticks(df['Label'][11:15])
ax[2].set_yticks(df['Occurances'][11:15])
ax[2].set_xlabel('Fragments of Right Iliac')
ax[2].set_ylabel('Occurrences in each image')


plt.show()

# %%
import matplotlib.pyplot as plt
plt.bar(df['Label'][1:5], df['Occurances'][1:5])
plt.xticks(df['Label'][1:5])
plt.yticks(df['Occurances'][1:5])
plt.xlabel('Fragments of Sacrum')
plt.ylabel('Occurrences in each image')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.bar(df['Label'][5:11], df['Occurances'][5:11])
plt.xticks(df['Label'][5:11])
plt.yticks(df['Occurances'][5:11])
plt.xlabel('Fragments of Left Iliac')
plt.ylabel('Occurrences in each image')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.bar(df['Label'][11:15], df['Occurances'][11:15])
plt.xticks(df['Label'][11:15])
plt.yticks(df['Occurances'][11:15])
plt.xlabel('Fragments of Right Iliac')
plt.ylabel('Occurrences in each image')
plt.show()

# %%
import pandas as pd

# %%
df = pd.read_csv("/home/shirshak/Pengwin_Submission_Portal/zzz_tests/get_all_size_as_list_new.csv").drop('Unnamed: 0', axis=1)#.drop(['Unnamed: 0', 'Name'], axis=1)

# %%
df
# Out:
#     Label                    All Pixel Counts and Occurances
# 0       0  [50320.869, 20094.389, 31282.517, 15028.073, 6...
# 1       1  [223.798, 175.924, 181.277, 119.763, 155.991, ...
# 2       2  [21.264, 30.142, 34.888, 51.115, 43.573, 42.87...
# 3       3  [22.206, 34.029, 3.915, 60.649, 41.303, 2.234,...
# 4       4                                           [45.011]
# 5      11  [371.959, 273.008, 236.07, 204.558, 173.957, 2...
# 6      12  [31.175, 19.376, 20.531, 68.065, 14.991, 22.98...
# 7      13  [35.877, 9.068, 70.468, 70.898, 3.932, 81.795,...
# 8      14  [3.949, 1.623, 4.167, 22.37, 1.705, 7.437, 2.0...
# 9      15                                            [2.372]
# 10     16                                            [6.621]
# 11     21  [412.199, 255.404, 280.919, 214.008, 215.828, ...
# 12     22  [8.321, 10.061, 21.386, 11.136, 3.949, 64.955,...
# 13     23  [10.29, 7.189, 2.394, 32.652, 8.222, 41.205, 7...
# ...

# %%
df.columns
# Out:
# Index(['Label', 'All Pixel Counts and Occurances'], dtype='object')

# %%
import ast
def convert_string_to_list(data):
    data = ast.literal_eval(data)
    return data

# %%
df['All Pixel Counts and Occurances'][0]
# Out:
# '[50320.869, 20094.389, 31282.517, 15028.073, 65090.056, 21671.678, 57324.414, 38026.523, 15368.411, 64898.945, 61673.436, 52903.367, 47243.628, 27121.235, 22540.12, 36672.699, 44178.338, 47041.523, 34414.922, 43990.233, 43889.395, 63397.459, 23583.685, 44017.562, 25083.023, 47730.072, 44530.378, 21773.817, 48088.712, 43523.272, 49177.074, 44150.999, 18788.451, 54204.732, 26825.607, 30459.653, 52888.36, 44105.65, 22396.127, 44248.141, 30165.998, 52229.205, 52695.657, 12458.777, 19504.469, 43204.895, 34585.511, 66939.283, 42466.749, 20699.001, 53104.637, 54260.638, 40037.965, 54152.877, 42665.3, 26113.213, 42852.534, 33811.87, 52310.924, 20866.465, 44577.051, 25657.433, 20838.059, 43992.769, 44061.966, 39747.855, 27746.801, 47487.854, 59287.331, 31438.377, 15499.74, 20962.163, 41426.2, 64341.076, 55279.79, 44081.439, 37835.88, 24288.331, 16092.867, 54620.395, 18606.93, 31385.768, 40343.952, 49917.958, 22422.869, 15917.952, 21461.319, 31369.933, 44976.738, 59526.421, 34168.093, 58642.3
# ...

# %%
df['All Pixel Counts and Occurances'].apply(convert_string_to_list)
# Out:
# 0     [50320.869, 20094.389, 31282.517, 15028.073, 6...
# 1     [223.798, 175.924, 181.277, 119.763, 155.991, ...
# 2     [21.264, 30.142, 34.888, 51.115, 43.573, 42.87...
# 3     [22.206, 34.029, 3.915, 60.649, 41.303, 2.234,...
# 4                                              [45.011]
# 5     [371.959, 273.008, 236.07, 204.558, 173.957, 2...
# 6     [31.175, 19.376, 20.531, 68.065, 14.991, 22.98...
# 7     [35.877, 9.068, 70.468, 70.898, 3.932, 81.795,...
# 8     [3.949, 1.623, 4.167, 22.37, 1.705, 7.437, 2.0...
# 9                                               [2.372]
# 10                                              [6.621]
# 11    [412.199, 255.404, 280.919, 214.008, 215.828, ...
# 12    [8.321, 10.061, 21.386, 11.136, 3.949, 64.955,...
# 13    [10.29, 7.189, 2.394, 32.652, 8.222, 41.205, 7...
# 14    [7.837, 8.534, 15.125, 3.856, 54.182, 7.365, 1...
# Name: All Pixel Counts and Occurances, dtype: object

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize =(10, 7))
 
# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])
 

ax.boxplot(np.array(df['All Pixel Counts and Occurances'].apply(convert_string_to_list)[0]))
ax.set_xticklabels(['0th class'])
plt.show()

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv("/home/shirshak/Pengwin_Submission_Portal/zzz_tests/get_all_size_as_list_new.csv").drop('Unnamed: 0', axis=1)#.drop(['Unnamed: 0', 'Name'], axis=1)

# %%
df
# Out:
#     Label                    All Pixel Counts and Occurances
# 0       0  [50320.869, 20094.389, 31282.517, 15028.073, 6...
# 1       1  [223.798, 175.924, 181.277, 119.763, 155.991, ...
# 2       2  [21.264, 30.142, 34.888, 51.115, 43.573, 42.87...
# 3       3  [22.206, 34.029, 3.915, 60.649, 41.303, 2.234,...
# 4       4                                           [45.011]
# 5      11  [371.959, 273.008, 236.07, 204.558, 173.957, 2...
# 6      12  [31.175, 19.376, 20.531, 68.065, 14.991, 22.98...
# 7      13  [35.877, 9.068, 70.468, 70.898, 3.932, 81.795,...
# 8      14  [3.949, 1.623, 4.167, 22.37, 1.705, 7.437, 2.0...
# 9      15                                            [2.372]
# 10     16                                            [6.621]
# 11     21  [412.199, 255.404, 280.919, 214.008, 215.828, ...
# 12     22  [8.321, 10.061, 21.386, 11.136, 3.949, 64.955,...
# 13     23  [10.29, 7.189, 2.394, 32.652, 8.222, 41.205, 7...
# ...

# %%
fig, ax = plt.subplots()
ax.boxplot(np.array(df['All Pixel Counts and Occurances'].apply(convert_string_to_list)[1:]))
ax.set_xticklabels(['1', '2', '3', '4', '11', '12', '13', '14', '15', '16', '21', '22', '23', '24'])
ax.set_xlabel('Label')
ax.set_ylabel('Size of each label (cm3)')
ax.set_title('Label Vs Size of each label')
plt.show()

# %%
fig, ax = plt.subplots(1,3, sharey=True, constrained_layout=True)
fig.set_figheight(6)
fig.set_figwidth(12)
fig.set_constrained_layout_pads(hspace=0.0, h_pad=0.0)  


ax[0].boxplot(np.array(df['All Pixel Counts and Occurances'].apply(convert_string_to_list)[1:5]), showmeans=True)
ax[0].set_xticklabels(['1', '2', '3', '4'])
ax[0].set_xlabel('Sacrum Label')
ax[0].set_ylabel('Size of each label (cm3)')

ax[1].boxplot(np.array(df['All Pixel Counts and Occurances'].apply(convert_string_to_list)[5:11]), showmeans=True)
ax[1].set_xticklabels(['11', '12', '13', '14', '15', '16'])
ax[1].set_xlabel('Left Iliac Label')

ax[2].boxplot(np.array(df['All Pixel Counts and Occurances'].apply(convert_string_to_list)[11:15]), showmeans=True)
ax[2].set_xticklabels(['21', '22', '23', '24'])
ax[2].set_xlabel('Right Iliac Label')
# ax.set_title('Label Vs Size of each label')
# ax[0].grid(axis='y')
# ax[1].grid(axis='y')
# ax[2].grid(axis='y')
plt.show()
